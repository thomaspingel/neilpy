# %%
import neilpy
import rasterio
import numpy as np
import scipy.ndimage as ndi
from skimage.util import apply_parallel
import matplotlib.pyplot as plt
# Out:
# Traceback (most recent call last):
#
#   File "c:\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-1-bbaca27027cd>", line 1, in <module>
#     import neilpy
#
#   File "c:\Anaconda3\lib\site-packages\neilpy\__init__.py", line 1, in <module>
#     from .neilpy import *
#
#   File "c:\Anaconda3\lib\site-packages\neilpy\neilpy.py", line 52
#     '''
#     ^
# IndentationError: unexpected indent

# %%
with rasterio.open('../sample_data/sample_dem.tif') as src:
        Z = src.read(1)
        Zt = src.transform
        cellsize = Zt[0]

# %%
B = neilpy.pssm(Z,cellsize,ve=5)
plt.imshow(B)

# %%
neilpy.rasteri
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-09fccfe6d0f8> in <module>
# ----> 1 neilpy.rasterGi()
#
# AttributeError: module 'neilpy' has no attribute 'rasterGi'

# %%
plt.imshow(C,'gray')
