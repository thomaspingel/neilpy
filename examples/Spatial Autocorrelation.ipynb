# %%
import neilpy
import rasterio
import numpy as np
import scipy.ndimage as ndi
from skimage.util import apply_parallel
import matplotlib.pyplot as plt

# %%
with rasterio.open('../sample_data/sample_dem.tif') as src:
        Z = src.read(1)
        Zt = src.transform
        cellsize = Zt[0]

# %%
B = neilpy.pssm(Z,cellsize,ve=5)
plt.imshow(B)

# %%
neilpy.rasterGi(B,footprint=5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-c607fab1d091> in <module>
# ----> 1 neilpy.rasterGi(B,footprint=5)
#
# AttributeError: module 'neilpy' has no attribute 'rasterGi'

# %%
plt.imshow(C,'gray')
