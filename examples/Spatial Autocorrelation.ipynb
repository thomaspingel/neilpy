# %%
import neilpy
import rasterio
import numpy as np
import scipy.ndimage as ndi
from skimage.util import apply_parallel
import matplotlib.pyplot as plt

# %%
with rasterio.open('../sample_data/sample_dem.tif') as src:
        Z = src.read(1)
        Zt = src.transform
        cellsize = Zt[0]

# %%
B = neilpy.pssm(Z,cellsize,ve=1)
plt.imshow(B)

# %%
neilpy.rasterGi(B,footprint=6)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-11-94a412a8aa9d> in <module>
# ----> 1 neilpy.rasterGi(B,footprint=6)
#
# c:\Anaconda3\lib\site-packages\neilpy\neilpy.py in rasterGi(X, footprint, mode)
#     104
#     105     # Calculate Gi
# --> 106     a = (ndi.filters.generic_filter(X,np.nansum,footprint=w,mode=mode)) - (w_neighbors* mean_not_me)
#     107     b = np.sqrt((w_neighbors * (n-1-w_neighbors) * var_not_me) / (n-2))
#     108     del mean_not_me, var_not_me
#
# c:\Anaconda3\lib\site-packages\scipy\ndimage\filters.py in generic_filter(input, function, size, footprint, output, mode, cval, origin, extra_arguments, extra_keywords)
#    1426     fshape = [ii for ii in footprint.shape if ii > 0]
#    1427     if len(fshape) != input.ndim:
# -> 1428         raise RuntimeError('filter footprint array has incorrect shape.')
# ...

# %%
plt.imshow(C,'gray')

# %%
import scipy.ndimage as ndi

# %%
import numpy as np

# %%
ndi.generic_filter(np.random.rand(50,50),np.nansum,footprint=np.ones((5,5)))
# Out:
# array([[ 8.79372179,  9.40492586, 10.24610944, ..., 10.70234767,
#         11.44435489, 13.35813193],
#        [10.30522599, 10.95256069, 11.4900504 , ..., 10.17779287,
#         10.1625546 , 11.67090543],
#        [11.11944428, 10.86240912, 10.80767113, ..., 10.71465906,
#         10.2485527 , 11.21990082],
#        ...,
#        [ 9.0826341 , 10.80034929, 13.05083173, ...,  9.83182627,
#         10.23444227, 11.24021327],
#        [ 8.83649512, 10.93506791, 13.14335454, ...,  9.60508483,
#         10.65665652, 10.95850708],
#        [ 9.15477724, 11.22429213, 13.32185102, ...,  8.98732657,
#          9.72726918, 10.22437583]])
